# %% [markdown]
# <a href="https://colab.research.google.com/github/Raida03/AI360s2fall2024/blob/main/Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math
import matplotlib.pyplot as plt

# %%
def argmaxall(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxall returns a list of all of the elements with maximal value.
    """
    maxv = -math.inf       # negative infinity
    maxvals = []      # list of maximal elements
    for (e,v) in gen:
        if v>maxv:
            maxvals,maxv = [e], v
        elif v==maxv:
            maxvals.append(e)
    return maxvals

# %%
def argmaxe(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxe returns an element with maximal value.
    If there are multiple elements with the max value, one is returned at random.
    """
    return random.choice(argmaxall(gen))

# %%
def argmax(lst):
    """returns maximum index in a list"""
    return argmaxe(enumerate(lst))

def argmaxd(dct):
   """returns the arg max of a dictionary dct"""
   return argmaxe(dct.items())

def flip(prob):
    """return true with probability prob"""
    return random.random() < prob

# %%
def select_from_dist(item_prob_dist):
  #{6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2}
    """ returns a value from a distribution.
    item_prob_dist is an item:probability dictionary, where the
        probabilities sum to 1.
    returns an item chosen in proportion to its probability
    """
    ranreal = random.random()
    for (it,prob) in item_prob_dist.items():
        if ranreal < prob:
            return it
        else:
            ranreal -= prob
    raise RuntimeError(f"{item_prob_dist} is not a probability distribution")

# %%
"""Display Class"""

class Displayable(object):
    """Class that uses 'display'.
    The amount of detail is controlled by max_display_level
    """
    max_display_level = 1   # can be overridden in subclasses or instances

    def display(self,level,*args,**nargs):
        """print the arguments if level is less than or equal to the
        current max_display_level.
        level is an integer.
        the other arguments are whatever arguments print can take.
        """

        if level <= self.max_display_level:
            print(*args, **nargs)

# %%
class Plot_history(object):
    """Set up the plot for history of price and number in stock"""
    def __init__(self, ag, env):
        self.ag = ag
        self.env = env
        plt.ion()
        plt.xlabel("Time")
        plt.ylabel("Value")


    def plot_env_hist(self):
        """plot history of price and instock"""
        num = len(env.stock_history)
        plt.plot(range(num),env.price_history,label="Price")
        plt.plot(range(num),env.stock_history,label="In stock")
        plt.legend()
        #plt.draw()

    def plot_agent_hist(self):
        """plot history of buying"""
        num = len(ag.buy_history)
        plt.bar(range(1,num+1), ag.buy_history, label="Bought")
        plt.legend()
        #plt.draw()

# %%
"""Agent Conntroller"""

#from display import Displayable

class Agent(Displayable):

    def initial_action(self, percept):
        """return the initial action."""
        return self.select_action(percept)   # same as select_action

    def select_action(self, percept):
        """return the next action (and update internal state) given percept
        percept is variable:value dictionary
        """
        raise NotImplementedError("go")   # abstract method

# %%
"""Environment"""

class Environment(Displayable):
    def initial_percept(self):
        """returns the initial percept for the agent"""
        raise NotImplementedError("initial_percept")   # abstract method

    def do(self, action):
        """does the action in the environment
        returns the next percept """
        raise NotImplementedError("Environment.do")   # abstract method

# %%
"""Simulate"""

class Simulate(Displayable):
    """simulate the interaction between the agent and the environment
    for n time steps.
    Returns a pair of the agent state and the environment state.
    """
    def __init__(self,agent, environment):
        self.agent = agent
        self.env = environment
        self.percept = self.env.initial_percept()
        self.percept_history = [self.percept]
        self.action_history = []

    def go(self, n):
        for i in range(n):
            action = self.agent.select_action(self.percept)
            print(f"i={i} action={action}")

            self.percept = self.env.do(action,i)
            print(f"      percept={self.percept}")

# %%
"""TP Env"""

class TP_env(Environment):
    price_delta = [0, 0, 0, 25, 0, 20, 0, -69, 0, 0, 28, 0, 0, 0, -40,
        0, 65, 0, -45, 0, 0, 0, 20, 0, 6, 0, 6, 0, 0, 0, 6, 0, -13, 0, 6,
       0, 6, 0, -110, 0, 110, 0, 6, 0, -13, 0, 6, 0, 6, 0, 0, 0, 6, 0,
       -45, 0, 39, 0, 6, 0, 6, 0, 0, 0, 6, 0, -63, 50, 0, 6, 0, 6, 0, 0,
       0, 6, 0]
    sd = 5  # noise standard deviation

    def __init__(self):
        """paper buying agent"""
        self.time=0
        self.stock=20
        self.stock_history = []  # memory of the stock history
        self.price_history = []  # memory of the price history

    def initial_percept(self):
        """return initial percept"""
        self.stock_history.append(self.stock)
        self.price = round(234+self.sd*random.gauss(0,1))
        self.price_history.append(self.price)
        #print(f"Initial price: {self.price} ,instock: {self.stock}")
        return {'price': self.price,
                'instock': self.stock}

    def do(self, action, time_unit):
        """does action (buy) and returns percept consisting of price and instock"""
        used = select_from_dist({6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2})
        print(f"i={time_unit} used={used}")
        # used = select_from_dist({7:0.1, 6:0.2, 5:0.2, 4:0.3, 3:0.1, 2:0.1}) # uses more paper
        bought = action['buy']
        self.stock = self.stock+bought-used
        self.stock_history.append(self.stock)
        self.time += 1
        self.price =  round(self.price
                        + self.price_delta[self.time%len(self.price_delta)] # repeating pattern
                        + self.sd*random.gauss(0,1)) # plus randomness
        self.price_history.append(self.price)
        return {'price': self.price,
                'instock': self.stock}

# %%
class TP_agent(Agent):
    def __init__(self):
        self.spent = 0
        percept = env.initial_percept()
        self.ave = self.last_price = percept['price']
        self.instock = percept['instock']
        self.buy_history = []

    def select_action(self, percept):
        """return next action to carry out
        """
        self.last_price = percept['price']
        self.ave = self.ave+(self.last_price-self.ave)*0.05
        self.instock = percept['instock']
        if self.last_price < 0.2*self.ave and self.instock < 20:
            tobuy = 15
        elif self.instock < 10:
            tobuy = 10
        else:
            tobuy = 0
        self.spent += tobuy*self.last_price
        self.buy_history.append(tobuy)
        #print(f"agent buy:{tobuy}")
        return {'buy': tobuy}

# %%
env = TP_env()
ag = TP_agent()
sim = Simulate(ag,env)
sim.go(10)
ag.spent/env.time

sim.go(100);

sim.go(100);
print(f"agent spent ${ag.spent/100}")
pl = Plot_history(ag,env); pl.plot_env_hist(); pl.plot_agent_hist()
# Out:
# i=0 action={'buy': 0}
# i=0 used=2
#       percept={'price': 230, 'instock': 18}
# i=1 action={'buy': 0}
# i=1 used=3
#       percept={'price': 234, 'instock': 15}
# i=2 action={'buy': 0}
# i=2 used=5
#       percept={'price': 260, 'instock': 10}
# i=3 action={'buy': 0}
# i=3 used=2
#       percept={'price': 263, 'instock': 8}
# i=4 action={'buy': 10}
# i=4 used=3
#       percept={'price': 289, 'instock': 15}
# i=5 action={'buy': 0}
# i=5 used=1
#       percept={'price': 286, 'instock': 14}
# i=6 action={'buy': 0}
# i=6 used=2
#       percept={'price': 220, 'instock': 12}
# i=7 action={'buy': 0}
# i=7 used=5
#       percept={'price': 229, 'instock': 7}
# i=8 action={'buy': 10}
# i=8 used=3
#       percept={'price': 224, 'instock': 14}
# i=9 action={'buy': 0}
# i=9 used=6
#       percept={'price': 245, 'instock': 8}
# i=0 action={'buy': 10}
# i=0 used=1
#       percept={'price': 238, 'instock': 17}
# i=1 action={'buy': 0}
# i=1 used=2
#       percept={'price': 250, 'instock': 15}
# i=2 action={'buy': 0}
# i=2 used=4
#       percept={'price': 243, 'instock': 11}
# i=3 action={'buy': 0}
# i=3 used=3
#       percept={'price': 216, 'instock': 8}
# i=4 action={'buy': 10}
# i=4 used=2
#       percept={'price': 219, 'instock': 16}
# i=5 action={'buy': 0}
# i=5 used=2
#       percept={'price': 294, 'instock': 14}
# i=6 action={'buy': 0}
# i=6 used=3
#       percept={'price': 292, 'instock': 11}
# i=7 action={'buy': 0}
# i=7 used=3
#       percept={'price': 251, 'instock': 8}
# i=8 action={'buy': 10}
# i=8 used=5
#       percept={'price': 242, 'instock': 13}
# i=9 action={'buy': 0}
# i=9 used=2
#       percept={'price': 241, 'instock': 11}
# i=10 action={'buy': 0}
# i=10 used=2
#       percept={'price': 241, 'instock': 9}
# i=11 action={'buy': 10}
# i=11 used=1
#       percept={'price': 266, 'instock': 18}
# i=12 action={'buy': 0}
# i=12 used=3
#       percept={'price': 266, 'instock': 15}
# i=13 action={'buy': 0}
# i=13 used=2
#       percept={'price': 274, 'instock': 13}
# i=14 action={'buy': 0}
# i=14 used=1
#       percept={'price': 268, 'instock': 12}
# i=15 action={'buy': 0}
# i=15 used=2
#       percept={'price': 270, 'instock': 10}
# i=16 action={'buy': 0}
# i=16 used=3
#       percept={'price': 265, 'instock': 7}
# i=17 action={'buy': 10}
# i=17 used=6
#       percept={'price': 265, 'instock': 11}
# i=18 action={'buy': 0}
# i=18 used=3
#       percept={'price': 273, 'instock': 8}
# i=19 action={'buy': 10}
# i=19 used=4
#       percept={'price': 276, 'instock': 14}
# i=20 action={'buy': 0}
# i=20 used=6
#       percept={'price': 273, 'instock': 8}
# i=21 action={'buy': 10}
# i=21 used=6
#       percept={'price': 263, 'instock': 12}
# i=22 action={'buy': 0}
# i=22 used=1
#       percept={'price': 260, 'instock': 11}
# i=23 action={'buy': 0}
# i=23 used=3
#       percept={'price': 268, 'instock': 8}
# i=24 action={'buy': 10}
# i=24 used=2
#       percept={'price': 264, 'instock': 16}
# i=25 action={'buy': 0}
# i=25 used=2
#       percept={'price': 260, 'instock': 14}
# i=26 action={'buy': 0}
# i=26 used=3
#       percept={'price': 262, 'instock': 11}
# i=27 action={'buy': 0}
# i=27 used=3
#       percept={'price': 142, 'instock': 8}
# i=28 action={'buy': 10}
# i=28 used=4
#       percept={'price': 148, 'instock': 14}
# i=29 action={'buy': 0}
# i=29 used=3
#       percept={'price': 265, 'instock': 11}
# i=30 action={'buy': 0}
# i=30 used=3
#       percept={'price': 272, 'instock': 8}
# i=31 action={'buy': 10}
# i=31 used=6
#       percept={'price': 275, 'instock': 12}
# i=32 action={'buy': 0}
# i=32 used=6
#       percept={'price': 274, 'instock': 6}
# i=33 action={'buy': 10}
# i=33 used=5
#       percept={'price': 266, 'instock': 11}
# i=34 action={'buy': 0}
# i=34 used=1
#       percept={'price': 267, 'instock': 10}
# i=35 action={'buy': 0}
# i=35 used=3
#       percept={'price': 275, 'instock': 7}
# i=36 action={'buy': 10}
# i=36 used=5
#       percept={'price': 279, 'instock': 12}
# i=37 action={'buy': 0}
# i=37 used=1
#       percept={'price': 285, 'instock': 11}
# i=38 action={'buy': 0}
# i=38 used=3
#       percept={'price': 285, 'instock': 8}
# i=39 action={'buy': 10}
# i=39 used=1
#       percept={'price': 280, 'instock': 17}
# i=40 action={'buy': 0}
# i=40 used=3
#       percept={'price': 281, 'instock': 14}
# i=41 action={'buy': 0}
# i=41 used=3
#       percept={'price': 285, 'instock': 11}
# i=42 action={'buy': 0}
# i=42 used=3
#       percept={'price': 284, 'instock': 8}
# i=43 action={'buy': 10}
# i=43 used=3
#       percept={'price': 220, 'instock': 15}
# i=44 action={'buy': 0}
# i=44 used=1
#       percept={'price': 225, 'instock': 14}
# i=45 action={'buy': 0}
# i=45 used=3
#       percept={'price': 265, 'instock': 11}
# i=46 action={'buy': 0}
# i=46 used=3
#       percept={'price': 268, 'instock': 8}
# i=47 action={'buy': 10}
# i=47 used=3
#       percept={'price': 266, 'instock': 15}
# i=48 action={'buy': 0}
# i=48 used=6
#       percept={'price': 269, 'instock': 9}
# i=49 action={'buy': 10}
# i=49 used=2
#       percept={'price': 276, 'instock': 17}
# i=50 action={'buy': 0}
# i=50 used=6
#       percept={'price': 271, 'instock': 11}
# i=51 action={'buy': 0}
# i=51 used=1
#       percept={'price': 275, 'instock': 10}
# i=52 action={'buy': 0}
# i=52 used=1
#       percept={'price': 270, 'instock': 9}
# i=53 action={'buy': 10}
# i=53 used=6
#       percept={'price': 271, 'instock': 13}
# i=54 action={'buy': 0}
# i=54 used=4
#       percept={'price': 266, 'instock': 9}
# i=55 action={'buy': 10}
# i=55 used=1
#       percept={'price': 204, 'instock': 18}
# i=56 action={'buy': 0}
# i=56 used=1
#       percept={'price': 245, 'instock': 17}
# i=57 action={'buy': 0}
# i=57 used=2
#       percept={'price': 250, 'instock': 15}
# i=58 action={'buy': 0}
# i=58 used=3
#       percept={'price': 247, 'instock': 12}
# i=59 action={'buy': 0}
# i=59 used=3
#       percept={'price': 244, 'instock': 9}
# i=60 action={'buy': 10}
# i=60 used=3
#       percept={'price': 256, 'instock': 16}
# i=61 action={'buy': 0}
# i=61 used=3
#       percept={'price': 246, 'instock': 13}
# i=62 action={'buy': 0}
# i=62 used=3
#       percept={'price': 247, 'instock': 10}
# i=63 action={'buy': 0}
# i=63 used=6
#       percept={'price': 252, 'instock': 4}
# i=64 action={'buy': 10}
# i=64 used=1
#       percept={'price': 250, 'instock': 13}
# i=65 action={'buy': 0}
# i=65 used=6
#       percept={'price': 243, 'instock': 7}
# i=66 action={'buy': 10}
# i=66 used=2
#       percept={'price': 241, 'instock': 15}
# i=67 action={'buy': 0}
# i=67 used=3
#       percept={'price': 239, 'instock': 12}
# i=68 action={'buy': 0}
# i=68 used=1
#       percept={'price': 235, 'instock': 11}
# i=69 action={'buy': 0}
# i=69 used=3
#       percept={'price': 258, 'instock': 8}
# i=70 action={'buy': 10}
# i=70 used=2
#       percept={'price': 264, 'instock': 16}
# i=71 action={'buy': 0}
# i=71 used=6
#       percept={'price': 278, 'instock': 10}
# i=72 action={'buy': 0}
# i=72 used=3
#       percept={'price': 282, 'instock': 7}
# i=73 action={'buy': 10}
# i=73 used=1
#       percept={'price': 221, 'instock': 16}
# i=74 action={'buy': 0}
# i=74 used=2
#       percept={'price': 228, 'instock': 14}
# i=75 action={'buy': 0}
# i=75 used=5
#       percept={'price': 227, 'instock': 9}
# i=76 action={'buy': 10}
# i=76 used=2
#       percept={'price': 254, 'instock': 17}
# i=77 action={'buy': 0}
# i=77 used=3
#       percept={'price': 254, 'instock': 14}
# i=78 action={'buy': 0}
# i=78 used=6
#       percept={'price': 247, 'instock': 8}
# i=79 action={'buy': 10}
# i=79 used=1
#       percept={'price': 249, 'instock': 17}
# i=80 action={'buy': 0}
# i=80 used=2
#       percept={'price': 217, 'instock': 15}
# i=81 action={'buy': 0}
# i=81 used=3
#       percept={'price': 222, 'instock': 12}
# i=82 action={'buy': 0}
# i=82 used=3
#       percept={'price': 298, 'instock': 9}
# i=83 action={'buy': 10}
# i=83 used=5
#       percept={'price': 293, 'instock': 14}
# i=84 action={'buy': 0}
# i=84 used=5
#       percept={'price': 260, 'instock': 9}
# i=85 action={'buy': 10}
# i=85 used=2
#       percept={'price': 260, 'instock': 17}
# i=86 action={'buy': 0}
# i=86 used=1
#       percept={'price': 269, 'instock': 16}
# i=87 action={'buy': 0}
# i=87 used=2
#       percept={'price': 266, 'instock': 14}
# i=88 action={'buy': 0}
# i=88 used=1
#       percept={'price': 289, 'instock': 13}
# i=89 action={'buy': 0}
# i=89 used=2
#       percept={'price': 284, 'instock': 11}
# i=90 action={'buy': 0}
# i=90 used=3
#       percept={'price': 296, 'instock': 8}
# i=91 action={'buy': 10}
# i=91 used=4
#       percept={'price': 299, 'instock': 14}
# i=92 action={'buy': 0}
# i=92 used=1
#       percept={'price': 309, 'instock': 13}
# i=93 action={'buy': 0}
# i=93 used=2
#       percept={'price': 320, 'instock': 11}
# i=94 action={'buy': 0}
# i=94 used=2
#       percept={'price': 323, 'instock': 9}
# i=95 action={'buy': 10}
# i=95 used=1
#       percept={'price': 323, 'instock': 18}
# i=96 action={'buy': 0}
# i=96 used=3
#       percept={'price': 337, 'instock': 15}
# i=97 action={'buy': 0}
# i=97 used=5
#       percept={'price': 341, 'instock': 10}
# i=98 action={'buy': 0}
# i=98 used=2
#       percept={'price': 321, 'instock': 8}
# i=99 action={'buy': 10}
# i=99 used=2
#       percept={'price': 319, 'instock': 16}
# i=0 action={'buy': 0}
# i=0 used=3
#       percept={'price': 315, 'instock': 13}
# i=1 action={'buy': 0}
# i=1 used=4
#       percept={'price': 314, 'instock': 9}
# i=2 action={'buy': 10}
# i=2 used=2
#       percept={'price': 317, 'instock': 17}
# i=3 action={'buy': 0}
# i=3 used=2
#       percept={'price': 312, 'instock': 15}
# i=4 action={'buy': 0}
# i=4 used=1
#       percept={'price': 199, 'instock': 14}
# i=5 action={'buy': 0}
# i=5 used=1
#       percept={'price': 196, 'instock': 13}
# i=6 action={'buy': 0}
# i=6 used=3
#       percept={'price': 311, 'instock': 10}
# i=7 action={'buy': 0}
# i=7 used=2
#       percept={'price': 315, 'instock': 8}
# i=8 action={'buy': 10}
# i=8 used=6
#       percept={'price': 322, 'instock': 12}
# i=9 action={'buy': 0}
# i=9 used=4
#       percept={'price': 326, 'instock': 8}
# i=10 action={'buy': 10}
# i=10 used=4
#       percept={'price': 313, 'instock': 14}
# i=11 action={'buy': 0}
# i=11 used=1
#       percept={'price': 314, 'instock': 13}
# i=12 action={'buy': 0}
# i=12 used=6
#       percept={'price': 319, 'instock': 7}
# i=13 action={'buy': 10}
# i=13 used=1
#       percept={'price': 318, 'instock': 16}
# i=14 action={'buy': 0}
# i=14 used=5
#       percept={'price': 328, 'instock': 11}
# i=15 action={'buy': 0}
# i=15 used=3
#       percept={'price': 317, 'instock': 8}
# i=16 action={'buy': 10}
# i=16 used=4
#       percept={'price': 318, 'instock': 14}
# i=17 action={'buy': 0}
# i=17 used=3
#       percept={'price': 317, 'instock': 11}
# i=18 action={'buy': 0}
# i=18 used=1
#       percept={'price': 325, 'instock': 10}
# i=19 action={'buy': 0}
# i=19 used=3
#       percept={'price': 326, 'instock': 7}
# i=20 action={'buy': 10}
# i=20 used=2
#       percept={'price': 265, 'instock': 15}
# i=21 action={'buy': 0}
# i=21 used=2
#       percept={'price': 259, 'instock': 13}
# i=22 action={'buy': 0}
# i=22 used=3
#       percept={'price': 300, 'instock': 10}
# i=23 action={'buy': 0}
# i=23 used=4
#       percept={'price': 306, 'instock': 6}
# i=24 action={'buy': 10}
# i=24 used=1
#       percept={'price': 310, 'instock': 15}
# i=25 action={'buy': 0}
# i=25 used=4
#       percept={'price': 309, 'instock': 11}
# i=26 action={'buy': 0}
# i=26 used=6
#       percept={'price': 304, 'instock': 5}
# i=27 action={'buy': 10}
# i=27 used=5
#       percept={'price': 307, 'instock': 10}
# i=28 action={'buy': 0}
# i=28 used=2
#       percept={'price': 313, 'instock': 8}
# i=29 action={'buy': 10}
# i=29 used=2
#       percept={'price': 315, 'instock': 16}
# i=30 action={'buy': 0}
# i=30 used=1
#       percept={'price': 321, 'instock': 15}
# i=31 action={'buy': 0}
# i=31 used=3
#       percept={'price': 317, 'instock': 12}
# i=32 action={'buy': 0}
# i=32 used=3
#       percept={'price': 252, 'instock': 9}
# i=33 action={'buy': 10}
# i=33 used=3
#       percept={'price': 306, 'instock': 16}
# i=34 action={'buy': 0}
# i=34 used=2
#       percept={'price': 307, 'instock': 14}
# i=35 action={'buy': 0}
# i=35 used=2
#       percept={'price': 319, 'instock': 12}
# i=36 action={'buy': 0}
# i=36 used=3
#       percept={'price': 322, 'instock': 9}
# i=37 action={'buy': 10}
# i=37 used=1
#       percept={'price': 337, 'instock': 18}
# i=38 action={'buy': 0}
# i=38 used=4
#       percept={'price': 339, 'instock': 14}
# i=39 action={'buy': 0}
# i=39 used=3
#       percept={'price': 344, 'instock': 11}
# i=40 action={'buy': 0}
# i=40 used=2
#       percept={'price': 345, 'instock': 9}
# i=41 action={'buy': 10}
# i=41 used=4
#       percept={'price': 347, 'instock': 15}
# i=42 action={'buy': 0}
# i=42 used=3
#       percept={'price': 355, 'instock': 12}
# i=43 action={'buy': 0}
# i=43 used=4
#       percept={'price': 352, 'instock': 8}
# i=44 action={'buy': 10}
# i=44 used=3
#       percept={'price': 344, 'instock': 15}
# i=45 action={'buy': 0}
# i=45 used=1
#       percept={'price': 339, 'instock': 14}
# i=46 action={'buy': 0}
# i=46 used=2
#       percept={'price': 366, 'instock': 12}
# i=47 action={'buy': 0}
# i=47 used=2
#       percept={'price': 369, 'instock': 10}
# i=48 action={'buy': 0}
# i=48 used=1
#       percept={'price': 389, 'instock': 9}
# i=49 action={'buy': 10}
# i=49 used=3
#       percept={'price': 385, 'instock': 16}
# i=50 action={'buy': 0}
# i=50 used=4
#       percept={'price': 321, 'instock': 12}
# i=51 action={'buy': 0}
# i=51 used=3
#       percept={'price': 326, 'instock': 9}
# i=52 action={'buy': 10}
# i=52 used=5
#       percept={'price': 322, 'instock': 14}
# i=53 action={'buy': 0}
# i=53 used=5
#       percept={'price': 350, 'instock': 9}
# i=54 action={'buy': 10}
# i=54 used=3
#       percept={'price': 348, 'instock': 16}
# i=55 action={'buy': 0}
# i=55 used=4
#       percept={'price': 348, 'instock': 12}
# i=56 action={'buy': 0}
# i=56 used=3
#       percept={'price': 353, 'instock': 9}
# i=57 action={'buy': 10}
# i=57 used=4
#       percept={'price': 319, 'instock': 15}
# i=58 action={'buy': 0}
# i=58 used=3
#       percept={'price': 321, 'instock': 12}
# i=59 action={'buy': 0}
# i=59 used=3
#       percept={'price': 397, 'instock': 9}
# i=60 action={'buy': 10}
# i=60 used=3
#       percept={'price': 395, 'instock': 16}
# i=61 action={'buy': 0}
# i=61 used=3
#       percept={'price': 346, 'instock': 13}
# i=62 action={'buy': 0}
# i=62 used=1
#       percept={'price': 344, 'instock': 12}
# i=63 action={'buy': 0}
# i=63 used=3
#       percept={'price': 353, 'instock': 9}
# i=64 action={'buy': 10}
# i=64 used=5
#       percept={'price': 357, 'instock': 14}
# i=65 action={'buy': 0}
# i=65 used=4
#       percept={'price': 381, 'instock': 10}
# i=66 action={'buy': 0}
# i=66 used=3
#       percept={'price': 377, 'instock': 7}
# i=67 action={'buy': 10}
# i=67 used=6
#       percept={'price': 381, 'instock': 11}
# i=68 action={'buy': 0}
# i=68 used=6
#       percept={'price': 386, 'instock': 5}
# i=69 action={'buy': 10}
# i=69 used=6
#       percept={'price': 389, 'instock': 9}
# i=70 action={'buy': 10}
# i=70 used=3
#       percept={'price': 396, 'instock': 16}
# i=71 action={'buy': 0}
# i=71 used=3
#       percept={'price': 395, 'instock': 13}
# i=72 action={'buy': 0}
# i=72 used=1
#       percept={'price': 395, 'instock': 12}
# i=73 action={'buy': 0}
# i=73 used=3
#       percept={'price': 399, 'instock': 9}
# i=74 action={'buy': 10}
# i=74 used=1
#       percept={'price': 402, 'instock': 18}
# i=75 action={'buy': 0}
# i=75 used=3
#       percept={'price': 388, 'instock': 15}
# i=76 action={'buy': 0}
# i=76 used=5
#       percept={'price': 383, 'instock': 10}
# i=77 action={'buy': 0}
# i=77 used=2
#       percept={'price': 395, 'instock': 8}
# i=78 action={'buy': 10}
# i=78 used=3
#       percept={'price': 399, 'instock': 15}
# i=79 action={'buy': 0}
# i=79 used=1
#       percept={'price': 406, 'instock': 14}
# i=80 action={'buy': 0}
# i=80 used=6
#       percept={'price': 403, 'instock': 8}
# i=81 action={'buy': 10}
# i=81 used=1
#       percept={'price': 293, 'instock': 17}
# i=82 action={'buy': 0}
# i=82 used=1
#       percept={'price': 289, 'instock': 16}
# i=83 action={'buy': 0}
# i=83 used=3
#       percept={'price': 403, 'instock': 13}
# i=84 action={'buy': 0}
# i=84 used=1
#       percept={'price': 404, 'instock': 12}
# i=85 action={'buy': 0}
# i=85 used=4
#       percept={'price': 418, 'instock': 8}
# i=86 action={'buy': 10}
# i=86 used=3
#       percept={'price': 415, 'instock': 15}
# i=87 action={'buy': 0}
# i=87 used=1
#       percept={'price': 405, 'instock': 14}
# i=88 action={'buy': 0}
# i=88 used=4
#       percept={'price': 409, 'instock': 10}
# i=89 action={'buy': 0}
# i=89 used=3
#       percept={'price': 418, 'instock': 7}
# i=90 action={'buy': 10}
# i=90 used=3
#       percept={'price': 415, 'instock': 14}
# i=91 action={'buy': 0}
# i=91 used=1
#       percept={'price': 420, 'instock': 13}
# i=92 action={'buy': 0}
# i=92 used=1
#       percept={'price': 417, 'instock': 12}
# i=93 action={'buy': 0}
# i=93 used=2
#       percept={'price': 423, 'instock': 10}
# i=94 action={'buy': 0}
# i=94 used=3
#       percept={'price': 422, 'instock': 7}
# i=95 action={'buy': 10}
# i=95 used=3
#       percept={'price': 433, 'instock': 14}
# i=96 action={'buy': 0}
# i=96 used=1
#       percept={'price': 431, 'instock': 13}
# i=97 action={'buy': 0}
# i=97 used=3
#       percept={'price': 375, 'instock': 10}
# i=98 action={'buy': 0}
# i=98 used=3
#       percept={'price': 378, 'instock': 7}
# i=99 action={'buy': 10}
# i=99 used=1
#       percept={'price': 420, 'instock': 16}
# agent spent $1864.4
